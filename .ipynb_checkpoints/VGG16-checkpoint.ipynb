# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import layers

# %%
# Processes the dataset into training and validation distributions and identifies the different data classes.
# Sets up model parameters: validation split, batch size, etc.

def initiateGenerator(path):
    base_path = path
    print("\nTotal : ", end=" ")
    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(batch_size=32, directory=base_path)

    train_datagen = ImageDataGenerator(validation_split=0.3)

    print("\nFor Training : ", end=" ")
    train_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', subset='training')

    print("\nFor Val : ", end=" ")
    validation_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='validation', shuffle=False)

    class_names = train_dataset.class_names
    noOfClasses = len(class_names)
    print("\nNo of Classes : ", noOfClasses)
    print("Classes : ", class_names)

    plt.figure(figsize=(10, 10))
    for images, labels in train_dataset.take(1):
        for i in range(noOfClasses):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

    for image_batch, labels_batch in train_dataset:
        print("Image Shape : ",image_batch.shape)
        break
        
    return noOfClasses,class_names, train_generator, validation_generator

# %%
# Implements batch normalization. Benefits: speeds up training, higher learning rate 

def initiateNormalize():
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
    normalization_layer = layers.Rescaling(1./255)

    normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    image_batch, labels_batch = next(iter(normalized_ds))
    first_image = image_batch[0]
    print(np.min(first_image), np.max(first_image))

# %%
# Initializes the model and provides summary of its layers, parameters, and outputs

def initiateModel(noOfClasses):
    modelInput = tf.keras.applications.VGG16(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

def modelSummary(model):
    model.summary()

# %%
# Initializes the model's parameters: learning rate, loss function, weights, etc.

def initiateParams(className, model, lr):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
    checkpoint = ModelCheckpoint(className + 'VGG16.h5', verbose=1, save_best_only=True)
    
    return model, annealer, checkpoint

# %%
# Fits model on training data for the specified number of fixed epochs or iterations

def modelFit(model, annealer, checkpoint, epochs=20, batchSize = 256):

    history = model.fit(
      train_generator,
      validation_data=validation_generator,
      epochs=epochs,
      batch_size=batchSize,
      callbacks=[annealer, checkpoint],
      steps_per_epoch=len(train_generator),
      validation_steps=len(validation_generator)
    )
    
    return history

# %%
# Plots the training/validation metrics

def plotOutput(history, className, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(12, 12))
    plt.subplot(3, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(3, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    plt.savefig(className + '_graph.png')

# %%
# Specifies the model's accuracy and saves the weights

def evalModel(model):
    evl = model.evaluate(validation_generator)
    acc = evl[1]*100
    msg=f'Accuracy on the Test Set = {acc:5.2f} %'
    print(msg)
    
def saveModel(model, className):
    model.save(className + " - VGG16.h5")
    print("Model Saved!")

# %%
# Demonstrates the model's True Positive, True Negative, False Negative, and True Negative predictions for improved analysis

def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    plt.savefig(title + '.png')

# %%
# Plots the confusion matrix

def callPlot(model, className, classes):
    y_true = validation_generator.classes
    print("True : ", (y_true))

    y_pred = model.predict(validation_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)

    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = classes,
                          title        = className + "Confusion Matrix")

# %%
# Begin running the model: The following cells will run the model on the dataset specified for each cancer class.

mpath = '/Users/kenny/Desktop/Multi Cancer'
classPaths = os.listdir(mpath)

IMAGE_SIZE = [224, 224]
img_height = 224
img_width = 224
noOfClasses = 0
gEpochs = 20
lr = 0.001

for i in classPaths:
    print(i)
# Out:
# ALL
# Brain Cancer
# Breast Cancer
# Cervical Cancer
# Kidney Cancer
# Lung and Colon Cancer
# Lymphoma
# Oral Cancer

# %%
className = 'Cervical Cancer '
cpath = os.path.join(mpath, 'Cervical Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 25000 files belonging to 5 classes.
#
# For Training :  Found 17500 images belonging to 5 classes.
#
# For Val :  Found 7500 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['cervix_dyk', 'cervix_koc', 'cervix_mep', 'cervix_pab', 'cervix_sfi']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_1 (Dense)             (None, 5)                 125445
#
# =================================================================
# Total params: 14,840,133
# Trainable params: 125,445
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 547/547 [==============================] - ETA: 0s - loss: 1.5887 - accuracy: 0.9221
# Epoch 1: val_loss improved from inf to 0.43022, saving model to Cervical Cancer VGG16.h5
# 547/547 [==============================] - 790s 1s/step - loss: 1.5887 - accuracy: 0.9221 - val_loss: 0.4302 - val_accuracy: 0.9771 - lr: 0.0010
# Epoch 2/20
# 547/547 [==============================] - ETA: 0s - loss: 0.3930 - accuracy: 0.9823
# Epoch 2: val_loss did not improve from 0.43022
# 547/547 [==============================] - 789s 1s/step - loss: 0.3930 - accuracy: 0.9823 - val_loss: 0.6491 - val_accuracy: 0.9743 - lr: 0.0010
# Epoch 3/20
# 547/547 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.9885
# Epoch 3: val_loss did not improve from 0.43022
# 547/547 [==============================] - 791s 1s/step - loss: 0.2525 - accuracy: 0.9885 - val_loss: 0.5539 - val_accuracy: 0.9807 - lr: 0.0010
# Epoch 4/20
# 547/547 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.9901
# Epoch 4: val_loss did not improve from 0.43022
# 547/547 [==============================] - 791s 1s/step - loss: 0.2627 - accuracy: 0.9901 - val_loss: 0.6764 - val_accuracy: 0.9791 - lr: 0.0010
# Epoch 5/20
# 547/547 [==============================] - ETA: 0s - loss: 0.2894 - accuracy: 0.9903
# Epoch 5: val_loss did not improve from 0.43022
# 547/547 [==============================] - 793s 1s/step - loss: 0.2894 - accuracy: 0.9903 - val_loss: 0.7100 - val_accuracy: 0.9824 - lr: 0.0010
# Epoch 6/20
# 547/547 [==============================] - ETA: 0s - loss: 0.3093 - accuracy: 0.9910
# Epoch 6: val_loss did not improve from 0.43022
# 547/547 [==============================] - 792s 1s/step - loss: 0.3093 - accuracy: 0.9910 - val_loss: 0.5715 - val_accuracy: 0.9867 - lr: 0.0010
# Epoch 7/20
# 547/547 [==============================] - ETA: 0s - loss: 0.
20
# 547/547 [==============================] - ETA: 0s - loss: 0.1630 - accuracy: 0.9967
# Epoch 19: val_loss did not improve from 0.42300
# 547/547 [==============================] - 797s 1s/step - loss: 0.1630 - accuracy: 0.9967 - val_loss: 0.8829 - val_accuracy: 0.9881 - lr: 0.0010
# Epoch 20/20
# 547/547 [==============================] - ETA: 0s - loss: 0.1779 - accuracy: 0.9973
# Epoch 20: val_loss improved from 0.42300 to 0.40261, saving model to Cervical Cancer VGG16.h5
# 547/547 [==============================] - 799s 1s/step - loss: 0.1779 - accuracy: 0.9973 - val_loss: 0.4026 - val_accuracy: 0.9935 - lr: 0.0010
# 235/235 [==============================] - 239s 1s/step - loss: 0.4026 - accuracy: 0.9935
# Accuracy on the Test Set = 99.35 %
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# 235/235 [==============================] - 239s 1s/step
# Predicted :  [0 0 0 ... 4 4 4]

# %%
className = 'Lung and Colon Cancer '
cpath = os.path.join(mpath, 'Lung and Colon Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 25000 files belonging to 5 classes.
#
# For Training :  Found 17500 images belonging to 5 classes.
#
# For Val :  Found 7500 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['colon_aca', 'colon_bnt', 'lung_aca', 'lung_bnt', 'lung_scc']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 5)                 125445
#
# =================================================================
# Total params: 14,840,133
# Trainable params: 125,445
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 547/547 [==============================] - ETA: 0s - loss: 1.3071 - accuracy: 0.9399
# Epoch 1: val_loss improved from inf to 0.67718, saving model to Lung and Colon Cancer VGG16.h5
# 547/547 [==============================] - 807s 1s/step - loss: 1.3071 - accuracy: 0.9399 - val_loss: 0.6772 - val_accuracy: 0.9713 - lr: 0.0010
# Epoch 2/20
# 547/547 [==============================] - ETA: 0s - loss: 0.5075 - accuracy: 0.9790
# Epoch 2: val_loss did not improve from 0.67718
# 547/547 [==============================] - 800s 1s/step - loss: 0.5075 - accuracy: 0.9790 - val_loss: 0.8961 - val_accuracy: 0.9721 - lr: 0.0010
# Epoch 3/20
# 547/547 [==============================] - ETA: 0s - loss: 0.3471 - accuracy: 0.9870
# Epoch 3: val_loss improved from 0.67718 to 0.66346, saving model to Lung and Colon Cancer VGG16.h5
# 547/547 [==============================] - 800s 1s/step - loss: 0.3471 - accuracy: 0.9870 - val_loss: 0.6635 - val_accuracy: 0.9805 - lr: 0.0010
# Epoch 4/20
# 547/547 [==============================] - ETA: 0s - loss: 0.2321 - accuracy: 0.9919
# Epoch 4: val_loss did not improve from 0.66346
# 547/547 [==============================] - 799s 1s/step - loss: 0.2321 - accuracy: 0.9919 - val_loss: 1.0008 - val_accuracy: 0.9773 - lr: 0.0010
# Epoch 5/20
# 547/547 [==============================] - ETA: 0s - loss: 0.2400 - accuracy: 0.9920
# Epoch 5: val_loss did not improve from 0.66346
# 547/547 [==============================] - 798s 1s/step - loss: 0.2400 - accuracy: 0.9920 - val_loss: 1.3157 - val_accuracy: 0.9747 - lr: 0.0010
# Epoch 6/20
# 547/547 [==============================] - ETA: 0s - loss: 0.2020 - accuracy: 0.9932
# Epoch 6: val_loss did not improve from 0.66346
# 547/547 [==============================] - 800s 1s/step - loss: 0.2020 - accuracy: 0.9932 - val_loss: 1.2005 - val_accuracy: 0.9765 - lr: 0.0010
# Epoch 7/20
# 547/547 [==============================] - ETA: 0s - loss: 0.2045 - accuracy: 0.9938
# Epoch 7: val_loss did not improve from 0.66346
# 547/547 [==============================] - 801s 1s/step - loss: 0.2045 - accuracy: 0.9938 - val_loss: 0.9298 - val_accuracy: 0.9832 - lr: 0.0010
# Epoch
20
# 547/547 [==============================] - ETA: 0s - loss: 0.1458 - accuracy: 0.9969
# Epoch 19: val_loss did not improve from 0.66346
# 547/547 [==============================] - 795s 1s/step - loss: 0.1458 - accuracy: 0.9969 - val_loss: 1.5792 - val_accuracy: 0.9847 - lr: 0.0010
# Epoch 20/20
# 547/547 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.9974
# Epoch 20: val_loss did not improve from 0.66346
# 547/547 [==============================] - 795s 1s/step - loss: 0.1254 - accuracy: 0.9974 - val_loss: 1.8376 - val_accuracy: 0.9820 - lr: 0.0010
# 235/235 [==============================] - 238s 1s/step - loss: 1.8376 - accuracy: 0.9820
# Accuracy on the Test Set = 98.20 %
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# 235/235 [==============================] - 237s 1s/step
# Predicted :  [0 0 0 ... 4 4 4]

# %%
className = 'Oral Cancer '
cpath = os.path.join(mpath, 'Oral Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10002 files belonging to 2 classes.
#
# For Training :  Found 7002 images belonging to 2 classes.
#
# For Val :  Found 3000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['oral_normal', 'oral_scc']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  dense_3 (Dense)             (None, 2)                 50178
#
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 219/219 [==============================] - ETA: 0s - loss: 6.7313 - accuracy: 0.7355
# Epoch 1: val_loss improved from inf to 5.72654, saving model to Oral Cancer VGG16.h5
# 219/219 [==============================] - 319s 1s/step - loss: 6.7313 - accuracy: 0.7355 - val_loss: 5.7265 - val_accuracy: 0.7820 - lr: 0.0010
# Epoch 2/20
# 219/219 [==============================] - ETA: 0s - loss: 2.5744 - accuracy: 0.8840
# Epoch 2: val_loss improved from 5.72654 to 5.13127, saving model to Oral Cancer VGG16.h5
# 219/219 [==============================] - 317s 1s/step - loss: 2.5744 - accuracy: 0.8840 - val_loss: 5.1313 - val_accuracy: 0.8273 - lr: 0.0010
# Epoch 3/20
# 219/219 [==============================] - ETA: 0s - loss: 1.4585 - accuracy: 0.9263
# Epoch 3: val_loss did not improve from 5.13127
# 219/219 [==============================] - 317s 1s/step - loss: 1.4585 - accuracy: 0.9263 - val_loss: 5.8120 - val_accuracy: 0.8227 - lr: 0.0010
# Epoch 4/20
# 219/219 [==============================] - ETA: 0s - loss: 1.0879 - accuracy: 0.9416
# Epoch 4: val_loss did not improve from 5.13127
# 219/219 [==============================] - 317s 1s/step - loss: 1.0879 - accuracy: 0.9416 - val_loss: 6.6946 - val_accuracy: 0.8207 - lr: 0.0010
# Epoch 5/20
# 219/219 [==============================] - ETA: 0s - loss: 0.9668 - accuracy: 0.9519
# Epoch 5: val_loss did not improve from 5.13127
# 219/219 [==============================] - 317s 1s/step - loss: 0.9668 - accuracy: 0.9519 - val_loss: 7.4839 - val_accuracy: 0.8157 - lr: 0.0010
# Epoch 6/20
# 219/219 [==============================] - ETA: 0s - loss: 0.9569 - accuracy: 0.9553
# Epoch 6: val_loss did not improve from 5.13127
# 219/219 [==============================] - 317s 1s/step - loss: 0.9569 - accuracy: 0.9553 - val_loss: 7.7279 - val_accuracy: 0.8210 - lr: 0.0010
# Epoch 7/20
# 219/219 [==============================] - ETA: 0s - loss: 0.7806 - accuracy: 0.9649
# Epoch 7: val_loss did not improve from 5.13127
# 219/219 [==============================] - 317s 1s/step - loss: 0.7806 - accuracy: 0.9649 - val_loss: 7.4924 - val_accuracy: 0.8457 - lr: 0.0010
# Epoch 8/20
# 219/219 [==============================] - ETA: 0s - loss: 0.5462 - accuracy: 0.9719
# Epoch 8: val_loss did not improve from 5.13127
# 219/219 [==============================] - 317s 1s/step - loss:

noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 20000 files belonging to 4 classes.
#
# For Training :  Found 14000 images belonging to 4 classes.
#
# For Val :  Found 6000 images belonging to 4 classes.
#
# No of Classes :  4
# Classes :  ['all_benign', 'all_early', 'all_pre', 'all_pro']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_4 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 4)                 100356
#
# =================================================================
# Total params: 14,815,044
# Trainable params: 100,356
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 438/438 [==============================] - ETA: 0s - loss: 1.0397 - accuracy: 0.9450
# Epoch 1: val_loss improved from inf to 0.29122, saving model to ALL VGG16.h5
# 438/438 [==============================] - 636s 1s/step - loss: 1.0397 - accuracy: 0.9450 - val_loss: 0.2912 - val_accuracy: 0.9832 - lr: 0.0010
# Epoch 2/20
# 438/438 [==============================] - ETA: 0s - loss: 0.1800 - accuracy: 0.9884
# Epoch 2: val_loss did not improve from 0.29122
# 438/438 [==============================] - 633s 1s/step - loss: 0.1800 - accuracy: 0.9884 - val_loss: 0.4484 - val_accuracy: 0.9823 - lr: 0.0010
# Epoch 3/20
# 438/438 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9896
# Epoch 3: val_loss did not improve from 0.29122
# 438/438 [==============================] - 634s 1s/step - loss: 0.2308 - accuracy: 0.9896 - val_loss: 0.4123 - val_accuracy: 0.9853 - lr: 0.0010
# Epoch 4/20
# 438/438 [==============================] - ETA: 0s - loss: 0.1733 - accuracy: 0.9926
# Epoch 4: val_loss did not improve from 0.29122
# 438/438 [==============================] - 633s 1s/step - loss: 0.1733 - accuracy: 0.9926 - val_loss: 0.4725 - val_accuracy: 0.9848 - lr: 0.0010
# Epoch 5/20
# 438/438 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 0.9943
# Epoch 5: val_loss did not improve from 0.29122
# 438/438 [==============================] - 633s 1s/step - loss: 0.1488 - accuracy: 0.9943 - val_loss: 0.3177 - val_accuracy: 0.9905 - lr: 0.0010
# Epoch 6/20
# 438/438 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9960
# Epoch 6: val_loss did not improve from 0.29122
# 438/438 [==============================] - 632s 1s/step - loss: 0.0899 - accuracy: 0.9960 - val_loss: 0.3329 - val_accuracy: 0.9882 - lr: 0.0010
# Epoch 7/20
# 438/438 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9958
# Epoch 7: val_loss did not improve from 0.29122
# 438/438 [==============================] - 633s 1s/step - loss: 0.1241 - accuracy: 0.9958 - val_loss: 0.5894 - val_accuracy: 0.9845 - lr: 0.0010
# Epoch 8/20
# 438/438 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9966
# Epoch 8: val_loss did not improve from 0.29122
# 438/438 [==============================] - 633s 1s/step - loss: 0.0956 - accuracy: 0.9966 - val_loss: 1.5078 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 9/20
# 438/438 [==============================] - ETA: 0s - loss: 0.1573 - accuracy: 0.9953
# Epoch 9: val_loss did not improve from 0.29122
# 438/438 [==============================] - 633s 1s/step - loss: 0.1573 - accuracy: 0.9953 - val_loss: 1.3248 - val_accuracy: 0.9733 - lr: 0.0010
# Epoch 10/20
# 438/438 [==============================] - ETA: 0s - loss: 0.1074 - accuracy: 0.9969
# Epoch 10: val_loss did not improve from 0.29122
# 438/438 [==============================] - 633s 1s/step - loss: 0.1074 - accuracy: 0.9969 - val_loss: 0.3939 - val_accuracy: 0.9918 - lr: 0.0010
# Epoch 11/20
# 438/438 [==============================] - ETA: 0s - loss: 0.1108 - accuracy: 0.9965
# Epoch 11: val_loss did not improve from 0.29122
# 438/438 [==============================] - 633s 1s/step - loss: 0.1108 - accuracy: 0.9965 - val_loss: 0.4059 - val_accuracy: 0.9903 - lr: 0.0010
# Epoch 12/20
# 438/438 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9974
# Epoch 12: val_loss did not improve from 0.29122
# 438/438 [==============================] - 633s 1s/step - loss: 0.0770 - accuracy: 0.9974 - val_loss: 0.4849 - val_accuracy: 0.9910 - lr: 0.0010
# Epoch 13/20
# 438/438 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9964
# Epoch 13: val_loss did not improve from 0.29122
# 438/438 [==============================] - 633s 1s/step - loss: 0.1162 - accuracy: 0.9964 - val_loss: 0.3454 - val_accuracy: 0.9935 - lr: 0.0010
# Epoch 14/20
# 438/438 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9986
# Epoch 14: val_loss did not improve from 0.29122
# 438/438 [==============================] - 634s 1s/step - loss: 0.0659 - accuracy: 0.9986 - val_loss: 0.5101 - val_accuracy: 0.9910 - lr: 0.0010
# Epoch 15/20
# 438/438 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9984
# Epoch 15: val_loss did not improve from 0.29122
# 438/438 [==============================] - 632s 1s/step - loss: 0.0611 - accuracy: 0.9984 - val_loss: 0.4450 - val_accuracy: 0.9933 - lr: 0.0010
# Epoch 16/20
# 438/438 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9990
# Epoch 16: val_loss did not improve from 0.29122
# 438/438 [==============================] - 634s 1s/step - loss: 0.0464 - accuracy: 0.9990 - val_loss: 0.3122 - val_accuracy: 0.9950 - lr: 0.0010
# Epoch 17/20
# 438/438 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9991
# Epoch 17: val_loss did not improve from 0.29122
# 438/438 [==============================] - 636s 1s/step - loss: 0.0405 - accuracy: 0.9991 - val_loss: 0.4763 - val_accuracy: 0.9920 - lr: 0.0010
# Epoch 18/20
# 438/438 [==============================] - ETA: 0s - loss: 0.1729 - accuracy: 0.9967
# Epoch 18: val_loss did not improve from 0.29122
# 438/438 [==============================] - 634s 1s/step - loss: 0.1729 - accuracy: 0.9967 - val_loss: 1.2923 - val_accuracy: 0.9830 - lr: 0.0010
# Epoch 19/20
# 438/438 [==============================] - ETA: 0s - loss: 0.0720 - accuracy: 0.9988
# Epoch 19: val_loss did not improve from 0.29122
# 438/438 [==============================] - 636s 1s/step - loss: 0.0720 - accuracy: 0.9988 - val_loss: 0.4973 - val_accuracy: 0.9925 - lr: 0.0010
# Epoch 20/20
# 438/438 [==============================] - ETA: 0s - loss: 0.1826 - accuracy: 0.9965
# Epoch 20: val_loss did not improve from 0.29122
# 438/438 [==============================] - 635s 1s/step - loss: 0.1826 - accuracy: 0.9965 - val_loss: 0.6342 - val_accuracy: 0.9917 - lr: 0.0010
# 188/188 [==============================] - 189s 1s/step - loss: 0.6342 - accuracy: 0.9917
# Accuracy on the Test Set = 99.17 %
# Model Saved!
# True :  [0 0 0 ... 3 3 3]
# 188/188 [==============================] - 189s 1s/step
# Predicted :  [0 0 0 ... 3 3 3]

# %%
className = 'Kidney Cancer '
cpath = os.path.join(mpath, 'Kidney Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10000 files belonging to 2 classes.
#
# For Training :  Found 7000 images belonging to 2 classes.
#
# For Val :  Found 3000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['kidney_normal', 'kidney_tumor']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_5 (Flatten)         (None, 25088)             0
#
#  dense_5 (Dense)             (None, 2)                 50178
#
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 219/219 [==============================] - ETA: 0s - loss: 0.8222 - accuracy: 0.9749
# Epoch 1: val_loss improved from inf to 4.86147, saving model to Kidney Cancer VGG16.h5
# 219/219 [==============================] - 319s 1s/step - loss: 0.8222 - accuracy: 0.9749 - val_loss: 4.8615 - val_accuracy: 0.8577 - lr: 0.0010
# Epoch 2/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9973
# Epoch 2: val_loss did not improve from 4.86147
# 219/219 [==============================] - 316s 1s/step - loss: 0.0293 - accuracy: 0.9973 - val_loss: 13.3884 - val_accuracy: 0.7760 - lr: 0.0010
# Epoch 3/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9970
# Epoch 3: val_loss did not improve from 4.86147
# 219/219 [==============================] - 316s 1s/step - loss: 0.0262 - accuracy: 0.9970 - val_loss: 9.9692 - val_accuracy: 0.8497 - lr: 0.0010
# Epoch 4/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9979
# Epoch 4: val_loss improved from 4.86147 to 4.72105, saving model to Kidney Cancer VGG16.h5
# 219/219 [==============================] - 316s 1s/step - loss: 0.0339 - accuracy: 0.9979 - val_loss: 4.7211 - val_accuracy: 0.9260 - lr: 0.0010
# Epoch 5/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9984
# Epoch 5: val_loss did not improve from 4.72105
# 219/219 [==============================] - 316s 1s/step - loss: 0.0356 - accuracy: 0.9984 - val_loss: 8.2990 - val_accuracy: 0.8913 - lr: 0.0010
# Epoch 6/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9983
# Epoch 6: val_loss did not improve from 4.72105
# 219/219 [==============================] - 316s 1s/step - loss: 0.0193 - accuracy: 0.9983 - val_loss: 15.2256 - val_accuracy: 0.8117 - lr: 0.0010
# Epoch 7/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9999
# Epoch 7: val_loss did not improve from 4.72105
# 219/219 [==============================] - 317s 1s/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 15.6835 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 8/20
# 219/219 [==============================] - ETA: 0s - loss: 2.7349e-08 - accuracy: 1.0000
# Epoch 8: val_loss did not improve from 4.72105
# 219/219 [==============================] - 317s 1s/step - loss: 2.7349e-08 - accuracy: 1.0000 - val_loss: 15.6788 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 9/20
# 219/219 [==============================] - ETA: 0s - loss: 2.2342e-08 - accuracy: 1.0000
# Epoch 9: val_loss did not improve from 4.72105
# 219/219 [==============================] - 316s 1s/step - loss: 2.2342e-08 - accuracy: 1.0000 - val_loss: 15.6765 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 10/20
# 219/219 [==============================] - ETA: 0s - loss: 1.8136e-08 - accuracy: 1.0000
# Epoch 10: val_loss did not improve from 4.72105
# 219/219 [==============================] - 316s 1s/step - loss: 1.8136e-08 - accuracy: 1.0000 - val_loss: 15.6688 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 11/20
# 219/219 [==============================] - ETA: 0s - loss: 1.5326e-08 - accuracy: 1.0000
# Epoch 11: val_loss did not improve from 4.72105
# 219/219 [==============================] - 317s 1s/step - loss: 1.5326e-08 - accuracy: 1.0000 - val_loss: 15.6626 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 12/20
# 219/219 [==============================] - ETA: 0s - loss: 1.3130e-08 - accuracy: 1.0000
# Epoch 12: val_loss did not improve from 4.72105
# 219/219 [==============================] - 316s 1s/step - loss: 1.3130e-08 - accuracy: 1.0000 - val_loss: 15.6583 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 13/20
# 219/219 [==============================] - ETA: 0s - loss: 1.1393e-08 - accuracy: 1.0000
# Epoch 13: val_loss did not improve from 4.72105
# 219/219 [==============================] - 318s 1s/step - loss: 1.1393e-08 - accuracy: 1.0000 - val_loss: 15.6542 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 14/20
# 219/219 [==============================] - ETA: 0s - loss: 9.8771e-09 - accuracy: 1.0000
# Epoch 14: val_loss did not improve from 4.72105
# 219/219 [==============================] - 317s 1s/step - loss: 9.8771e-09 - accuracy: 1.0000 - val_loss: 15.6499 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 15/20
# 219/219 [==============================] - ETA: 0s - loss: 8.6170e-09 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 4.72105
# 219/219 [==============================] - 317s 1s/step - loss: 8.6170e-09 - accuracy: 1.0000 - val_loss: 15.6456 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 16/20
# 219/219 [==============================] - ETA: 0s - loss: 7.4590e-09 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 4.72105
# 219/219 [==============================] - 317s 1s/step - loss: 7.4590e-09 - accuracy: 1.0000 - val_loss: 15.6418 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 17/20
# 219/219 [==============================] - ETA: 0s - loss: 6.5905e-09 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 4.72105
# 219/219 [==============================] - 318s 1s/step - loss: 6.5905e-09 - accuracy: 1.0000 - val_loss: 15.6378 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 18/20
# 219/219 [==============================] - ETA: 0s - loss: 5.7560e-09 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 4.72105
# 219/219 [==============================] - 317s 1s/step - loss: 5.7560e-09 - accuracy: 1.0000 - val_loss: 15.6338 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 19/20
# 219/219 [==============================] - ETA: 0s - loss: 5.0408e-09 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 4.72105
# 219/219 [==============================] - 317s 1s/step - loss: 5.0408e-09 - accuracy: 1.0000 - val_loss: 15.6303 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 20/20
# 219/219 [==============================] - ETA: 0s - loss: 4.4448e-09 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 4.72105
# 219/219 [==============================] - 317s 1s/step - loss: 4.4448e-09 - accuracy: 1.0000 - val_loss: 15.6262 - val_accuracy: 0.8033 - lr: 0.0010
# 94/94 [==============================] - 95s 1s/step - loss: 15.6262 - accuracy: 0.8033
# Accuracy on the Test Set = 80.33 %
# Model Saved!
# True :  [0 0 0 ... 1 1 1]
# 94/94 [==============================] - 95s 1s/step
# Predicted :  [0 0 0 ... 1 1 1]

# %%
className = 'Breast Cancer '
cpath = os.path.join(mpath, 'Breast Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10000 files belonging to 2 classes.
#
# For Training :  Found 7000 images belonging to 2 classes.
#
# For Val :  Found 3000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['breast_benign', 'breast_malignant']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_6 (Flatten)         (None, 25088)             0
#
#  dense_6 (Dense)             (None, 2)                 50178
#
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 219/219 [==============================] - ETA: 0s - loss: 0.9504 - accuracy: 0.9689
# Epoch 1: val_loss improved from inf to 0.44166, saving model to Breast Cancer VGG16.h5
# 219/219 [==============================] - 323s 1s/step - loss: 0.9504 - accuracy: 0.9689 - val_loss: 0.4417 - val_accuracy: 0.9877 - lr: 0.0010
# Epoch 2/20
# 219/219 [==============================] - ETA: 0s - loss: 0.2433 - accuracy: 0.9901
# Epoch 2: val_loss did not improve from 0.44166
# 219/219 [==============================] - 320s 1s/step - loss: 0.2433 - accuracy: 0.9901 - val_loss: 0.6346 - val_accuracy: 0.9853 - lr: 0.0010
# Epoch 3/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9960
# Epoch 3: val_loss did not improve from 0.44166
# 219/219 [==============================] - 320s 1s/step - loss: 0.0628 - accuracy: 0.9960 - val_loss: 0.5788 - val_accuracy: 0.9890 - lr: 0.0010
# Epoch 4/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9967
# Epoch 4: val_loss did not improve from 0.44166
# 219/219 [==============================] - 321s 1s/step - loss: 0.0764 - accuracy: 0.9967 - val_loss: 0.6713 - val_accuracy: 0.9883 - lr: 0.0010
# Epoch 5/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.9963
# Epoch 5: val_loss did not improve from 0.44166
# 219/219 [==============================] - 320s 1s/step - loss: 0.0960 - accuracy: 0.9963 - val_loss: 0.8803 - val_accuracy: 0.9843 - lr: 0.0010
# Epoch 6/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9983
# Epoch 6: val_loss did not improve from 0.44166
# 219/219 [==============================] - 321s 1s/step - loss: 0.0392 - accuracy: 0.9983 - val_loss: 0.7315 - val_accuracy: 0.9850 - lr: 0.0010
# Epoch 7/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9986
# Epoch 7: val_loss did not improve from 0.44166
# 219/219 [==============================] - 321s 1s/step - loss: 0.0324 - accuracy: 0.9986 - val_loss: 0.9425 - val_accuracy: 0.9813 - lr: 0.0010
# Epoch 8/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9989
# Epoch 8: val_loss did not improve from 0.44166
# 219/219 [==============================] - 321s 1s/step - loss: 0.0218 - accuracy: 0.9989 - val_loss: 1.0863 - val_accuracy: 0.9837 - lr: 0.0010
# Epoch 9/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9969
# Epoch 9: val_loss did not improve from 0.44166
# 219/219 [==============================] - 321s 1s/step - loss: 0.0736 - accuracy: 0.9969 - val_loss: 0.9250 - val_accuracy: 0.9867 - lr: 0.0010
# Epoch 10/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9974
# Epoch 10: val_loss did not improve from 0.44166
# 219/219 [==============================] - 321s 1s/step - loss: 0.0477 - accuracy: 0.9974 - val_loss: 1.0534 - val_accuracy: 0.9813 - lr: 0.0010
# Epoch 11/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9986
# Epoch 11: val_loss did not improve from 0.44166
# 219/219 [==============================] - 322s 1s/step - loss: 0.0516 - accuracy: 0.9986 - val_loss: 2.1420 - val_accuracy: 0.9680 - lr: 0.0010
# Epoch 12/20
# 219/219 [==============================] - ETA: 0s - loss: 0.1319 - accuracy: 0.9964
# Epoch 12: val_loss did not improve from 0.44166
# 219/219 [==============================] - 322s 1s/step - loss: 0.1319 - accuracy: 0.9964 - val_loss: 1.0781 - val_accuracy: 0.9900 - lr: 0.0010
# Epoch 13/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9994
# Epoch 13: val_loss did not improve from 0.44166
# 219/219 [==============================] - 322s 1s/step - loss: 0.0205 - accuracy: 0.9994 - val_loss: 0.8906 - val_accuracy: 0.9853 - lr: 0.0010
# Epoch 14/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9986
# Epoch 14: val_loss did not improve from 0.44166
# 219/219 [==============================] - 323s 1s/step - loss: 0.0753 - accuracy: 0.9986 - val_loss: 2.5485 - val_accuracy: 0.9803 - lr: 0.0010
# Epoch 15/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9983
# Epoch 15: val_loss did not improve from 0.44166
# 219/219 [==============================] - 322s 1s/step - loss: 0.0738 - accuracy: 0.9983 - val_loss: 1.3649 - val_accuracy: 0.9817 - lr: 0.0010
# Epoch 16/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9994
# Epoch 16: val_loss did not improve from 0.44166
# 219/219 [==============================] - 322s 1s/step - loss: 0.0213 - accuracy: 0.9994 - val_loss: 1.2377 - val_accuracy: 0.9833 - lr: 0.0010
# Epoch 17/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9991
# Epoch 17: val_loss did not improve from 0.44166
# 219/219 [==============================] - 322s 1s/step - loss: 0.0313 - accuracy: 0.9991 - val_loss: 1.2805 - val_accuracy: 0.9853 - lr: 0.0010
# Epoch 18/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9989
# Epoch 18: val_loss did not improve from 0.44166
# 219/219 [==============================] - 322s 1s/step - loss: 0.0288 - accuracy: 0.9989 - val_loss: 1.9872 - val_accuracy: 0.9853 - lr: 0.0010
# Epoch 19/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9990
# Epoch 19: val_loss did not improve from 0.44166
# 219/219 [==============================] - 321s 1s/step - loss: 0.0358 - accuracy: 0.9990 - val_loss: 1.5689 - val_accuracy: 0.9873 - lr: 0.0010
# Epoch 20/20
# 219/219 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9984
# Epoch 20: val_loss did not improve from 0.44166
# 219/219 [==============================] - 321s 1s/step - loss: 0.0916 - accuracy: 0.9984 - val_loss: 3.9565 - val_accuracy: 0.9620 - lr: 0.0010
# 94/94 [==============================] - 96s 1s/step - loss: 3.9565 - accuracy: 0.9620
# Accuracy on the Test Set = 96.20 %
# Model Saved!
# True :  [0 0 0 ... 1 1 1]
# 94/94 [==============================] - 96s 1s/step
# Predicted :  [0 0 0 ... 1 1 1]

# %%
className = 'Lymphoma '
cpath = os.path.join(mpath, 'Lymphoma')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 15000 files belonging to 3 classes.
#
# For Training :  Found 10500 images belonging to 3 classes.
#
# For Val :  Found 4500 images belonging to 3 classes.
#
# No of Classes :  3
# Classes :  ['lymph_cll', 'lymph_fl', 'lymph_mcl']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_7 (Flatten)         (None, 25088)             0
#
#  dense_7 (Dense)             (None, 3)                 75267
#
# =================================================================
# Total params: 14,789,955
# Trainable params: 75,267
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 329/329 [==============================] - ETA: 0s - loss: 5.1309 - accuracy: 0.6679
# Epoch 1: val_loss improved from inf to 3.79554, saving model to Lymphoma VGG16.h5
# 329/329 [==============================] - 485s 1s/step - loss: 5.1309 - accuracy: 0.6679 - val_loss: 3.7955 - val_accuracy: 0.7449 - lr: 0.0010
# Epoch 2/20
# 329/329 [==============================] - ETA: 0s - loss: 2.2467 - accuracy: 0.8352
# Epoch 2: val_loss improved from 3.79554 to 3.35618, saving model to Lymphoma VGG16.h5
# 329/329 [==============================] - 480s 1s/step - loss: 2.2467 - accuracy: 0.8352 - val_loss: 3.3562 - val_accuracy: 0.7987 - lr: 0.0010
# Epoch 3/20
# 329/329 [==============================] - ETA: 0s - loss: 1.2723 - accuracy: 0.8943
# 329/329 [==============================] - ETA: 0s - loss: 0.8309 - accuracy: 0.9530
# Epoch 13: val_loss did not improve from 2.74393
# 329/329 [==============================] - 482s 1s/step - loss: 0.8309 - accuracy: 0.9530 - val_loss: 5.3395 - val_accuracy: 0.8413 - lr: 0.0010
# Epoch 14/20
# 329/329 [==============================] - ETA: 0s - loss: 0.4193 - accuracy: 0.9722
# Epoch 14: val_loss did not improve from 2.74393
# 329/329 [==============================] - 481s 1s/step - loss: 0.4193 - accuracy: 0.9722 - val_loss: 4.4537 - val_accuracy: 0.8556 - lr: 0.0010
# Epoch 15/20
# 329/329 [==============================] - ETA: 0s - loss: 0.6218 - accuracy: 0.9671
# Epoch 15: val_loss did not improve from 2.74393
# 329/329 [==============================] - 481s 1s/step - loss: 0.6218 - accuracy: 0.9671 - val_loss: 6.8321 - val_accuracy: 0.8238 - lr: 0.0010
# Epoch 16/20
# 329/329 [==============================] - ETA: 0s - loss: 0.4045 - accuracy: 0.9737
# Epoch 16: val_loss did not improve from 2.74393
# 329/329 [==============================] - 481s 1s/step - loss: 0.4045 - accuracy: 0.9737 - val_loss: 5.1427 - val_accuracy: 0.8500 - lr: 0.0010
# Epoch 17/20
# 329/329 [==============================] - ETA: 0s - loss: 0.4851 - accuracy: 0.9728
# Epoch 17: val_loss did not improve from 2.74393
# 329/329 [==============================] - 481s 1s/step - loss: 0.4851 - accuracy: 0.9728 - val_loss: 7.3941 - val_accuracy: 0.8153 - lr: 0.0010
# Epoch 18/20
# 329/329 [==============================] - ETA: 0s - loss: 0.4922 - accuracy: 0.9731
# Epoch 18: val_loss did not improve from 2.74393
# 329/329 [==============================] - 481s 1s/step - loss: 0.4922 - accuracy: 0.9731 - val_loss: 5.8983 - val_accuracy: 0.8484 - lr: 0.0010
# Epoch 19/20
# 329/329 [==============================] - ETA: 0s - loss: 0.2945 - accuracy: 0.9820
# Epoch 19: val_loss did not improve from 2.74393
# 329/329 [==============================] - 482s 1s/step - loss: 0.2945 - accuracy: 0.9820 - val_loss: 5.6650 - val_accuracy: 0.8502 - lr: 0.0010
# Epoch 20/20
# 329/329 [==============================] - ETA: 0s - loss: 0.3718 - accuracy: 0.9780
# Epoch 20: val_loss did not improve from 2.74393
# 329/329 [==============================] - 481s 1s/step - loss: 0.3718 - accuracy: 0.9780 - val_loss: 5.4912 - val_accuracy: 0.8560 - lr: 0.0010
# 141/141 [==============================] - 144s 1s/step - loss: 5.4912 - accuracy: 0.8560
# Accuracy on the Test Set = 85.60 %
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# 141/141 [==============================] - 143s 1s/step
# Predicted :  [0 0 0 ... 2 2 2]

# %%
className = 'Brain Cancer '
cpath = os.path.join(mpath, 'Brain Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 15000 files belonging to 3 classes.
#
# For Training :  Found 10500 images belonging to 3 classes.
#
# For Val :  Found 4500 images belonging to 3 classes.
#
# No of Classes :  3
# Classes :  ['brain_glioma', 'brain_menin', 'brain_tumor']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_8 (Flatten)         (None, 25088)             0
#
#  dense_8 (Dense)             (None, 3)                 75267
#
# =================================================================
# Total params: 14,789,955
# Trainable params: 75,267
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
#
[==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.9895
# Epoch 12: val_loss did not improve from 0.93540
# 329/329 [==============================] - 479s 1s/step - loss: 0.2832 - accuracy: 0.9895 - val_loss: 1.9729 - val_accuracy: 0.9682 - lr: 0.0010
# Epoch 13/20
# 329/329 [==============================] - ETA: 0s - loss: 0.1469 - accuracy: 0.9940
# Epoch 13: val_loss did not improve from 0.93540
# 329/329 [==============================] - 478s 1s/step - loss: 0.1469 - accuracy: 0.9940 - val_loss: 2.0093 - val_accuracy: 0.9676 - lr: 0.0010
# Epoch 14/20
# 329/329 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9954
# Epoch 14: val_loss did not improve from 0.93540
# 329/329 [==============================] - 478s 1s/step - loss: 0.1445 - accuracy: 0.9954 - val_loss: 1.7584 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 15/20
# 329/329 [==============================] - ETA: 0s - loss: 0.1815 - accuracy: 0.9931
# Epoch 15: val_loss did not improve from 0.93540
# 329/329 [==============================] - 478s 1s/step - loss: 0.1815 - accuracy: 0.9931 - val_loss: 2.2835 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 16/20
# 329/329 [==============================] - ETA: 0s - loss: 0.1884 - accuracy: 0.9926
# Epoch 16: val_loss did not improve from 0.93540
# 329/329 [==============================] - 478s 1s/step - loss: 0.1884 - accuracy: 0.9926 - val_loss: 2.0699 - val_accuracy: 0.9698 - lr: 0.0010
# Epoch 17/20
# 329/329 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9954
# Epoch 17: val_loss did not improve from 0.93540
# 329/329 [==============================] - 477s 1s/step - loss: 0.1193 - accuracy: 0.9954 - val_loss: 2.1613 - val_accuracy: 0.9727 - lr: 0.0010
# Epoch 18/20
# 329/329 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9942
# Epoch 18: val_loss did not improve from 0.93540
# 329/329 [==============================] - 479s 1s/step - loss: 0.1746 - accuracy: 0.9942 - val_loss: 2.2920 - val_accuracy: 0.9682 - lr: 0.0010
# Epoch 19/20
# 329/329 [==============================] - ETA: 0s - loss: 0.4033 - accuracy: 0.9900
# Epoch 19: val_loss did not improve from 0.93540
# 329/329 [==============================] - 477s 1s/step - loss: 0.4033 - accuracy: 0.9900 - val_loss: 5.4896 - val_accuracy: 0.9378 - lr: 0.0010
# Epoch 20/20
# 329/329 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9960
# Epoch 20: val_loss did not improve from 0.93540
# 329/329 [==============================] - 476s 1s/step - loss: 0.1391 - accuracy: 0.9960 - val_loss: 2.4306 - val_accuracy: 0.9684 - lr: 0.0010
# 141/141 [==============================] - 143s 1s/step - loss: 2.4306 - accuracy: 0.9684
# Accuracy on the Test Set = 96.84 %
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# 141/141 [==============================] - 142s 1s/step
# Predicted :  [0 0 0 ... 2 1 2]

# %% [markdown]
# These are the resources we used to base our model off of:
# https://www.tensorflow.org/tutorials/images/cnn
# https://medium.com/geekculture/introduction-to-convolutional-neural-network-with-tensorflow-and-keras-cb52cdc66eaf
# https://towardsdatascience.com/step-by-step-vgg16-implementation-in-keras-for-beginners-a833c686ae6c
# https://www.kaggle.com/code/blurredmachine/vggnet-16-architecture-a-complete-guide/notebook
